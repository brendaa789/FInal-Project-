# %%
import pandas as pd

# %%
df = pd.read_csv("GSE150910_gene-level_count_file.csv.gz", encoding="utf-8")

# %%
display(df)
# Out:
#            symbol  chp_26  chp_31  chp_34  chp_38  chp_1  chp_3  chp_4  \
# 0          TSPAN6    1361     993     351     613    841    565   1093
# 1            TNMD       5      13       0       0      0      6      3
# 2            DPM1    1929    2775    1894    2007   1436   1923   1956
# 3           SCYL3     176     216     208     218    162    137    242
# 4        C1orf112      93     143      97     148     98    128    102
# ...           ...     ...     ...     ...     ...    ...    ...    ...
# 18833  AC055839.2     759     354     202     358    756    719    595
# 18834  AC242843.1      27      37      71      84     29     41     45
# 18835     SPDYE17       3       1       3       2      3      3      3
# 18836  AC022137.3      71      51      60     106     26     42     50
# 18837  AC007244.1       0      12       0      21      0      0      0
#
#        chp_11  chp_5  ...  chp_106  chp_108  chp_109  chp_110  chp_111  \
# ...

# %%
pd.set_option('display.max_columns', None)
display(df)
# Out:
#            symbol  chp_26  chp_31  chp_34  chp_38  chp_1  chp_3  chp_4  \
# 0          TSPAN6    1361     993     351     613    841    565   1093
# 1            TNMD       5      13       0       0      0      6      3
# 2            DPM1    1929    2775    1894    2007   1436   1923   1956
# 3           SCYL3     176     216     208     218    162    137    242
# 4        C1orf112      93     143      97     148     98    128    102
# ...           ...     ...     ...     ...     ...    ...    ...    ...
# 18833  AC055839.2     759     354     202     358    756    719    595
# 18834  AC242843.1      27      37      71      84     29     41     45
# 18835     SPDYE17       3       1       3       2      3      3      3
# 18836  AC022137.3      71      51      60     106     26     42     50
# 18837  AC007244.1       0      12       0      21      0      0      0
#
#        chp_11  chp_5  chp_9  chp_8  chp_10  chp_13  chp_14  chp_21  chp_19  \
# ...
